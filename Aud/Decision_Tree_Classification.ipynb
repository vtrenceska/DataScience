# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/DataScience/Auditoriski/data/bill_authentication.csv')

# %%
df
# Out:
#       Variance  Skewness  Curtosis  Entropy  Class
# 0      3.62160   8.66610   -2.8073 -0.44699      0
# 1      4.54590   8.16740   -2.4586 -1.46210      0
# 2      3.86600  -2.63830    1.9242  0.10645      0
# 3      3.45660   9.52280   -4.0112 -3.59440      0
# 4      0.32924  -4.45520    4.5718 -0.98880      0
# ...        ...       ...       ...      ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1
#
# [1372 rows x 5 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df[df.columns[:-1]],df['Class'],test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report, f1_score, accuracy_score

# %%
print(confusion_matrix(Y_test,y_pred))
print(classification_report(Y_test,y_pred))
f1_score(Y_test,y_pred)
# Out:
# [[154   0]
#  [  3 118]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       154
#            1       1.00      0.98      0.99       121
#
#     accuracy                           0.99       275
#    macro avg       0.99      0.99      0.99       275
# weighted avg       0.99      0.99      0.99       275
# 0.9874476987447699

# %%
# !pip install six

# %%
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image

# %%
clf = DecisionTreeClassifier(criterion='entropy',max_depth=3)

# %%
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
y_pred = clf.predict(X_test)

# %%
f1_score(Y_test,y_pred)
# Out:
# 0.9626556016597511

# %%
dot_data = StringIO()

# %%
export_graphviz(clf, out_file=dot_data, filled=True, rounded=True, special_characters=True,
                feature_names=df.columns[:-1], class_names=['0','1'])

# %%
import pydotplus

# %%
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
df = pd.read_csv('/content/drive/MyDrive/DataScience/Auditoriski/data/Position_Salaries.csv')

# %%
df
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df[df.columns[1:-1]], df['Salary'], test_size=0.2)

# %%
df2 = pd.read_csv('/content/drive/MyDrive/DataScience/Auditoriski/data/50_Startups.csv')

# %%
df2
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df2.drop(columns=['State','Administration'],inplace=True)

# %%
sns.pairplot(df2)

# %%
X_train2,X_test2,Y_train2,Y_test2 = train_test_split(df2[df2.columns[:-1]], df2['Profit'], test_size=0.2)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
reg = DecisionTreeRegressor()

# %%
reg.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.2109375

# %%
reg2 = DecisionTreeRegressor()

# %%
reg2.fit(X_train2,Y_train2)
# Out:
# DecisionTreeRegressor()

# %%
y_pred2 = reg2.predict(X_test2)

# %%
r2_score(Y_test2,y_pred2)
# Out:
# 0.9103523800810684

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.scatter(X_train, Y_train, color='red')
plt.plot(X_train, reg.predict(X_train), color='blue')

# %%
# First well create the 3d figure.
fig = plt.figure(figsize = (10,10))
ax = plt.axes(projection='3d')

#Next well pull out the datapoints for each axis
zdata = Y_train2
xdata = X_train2.iloc[:,0]
ydata = X_train2.iloc[:, 1]
#Now we plot the points
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Reds', s = 50);

#Next we need to make x and y dimensions for the data.
xline = np.linspace(min(xdata), max(xdata), 50)
yline = np.linspace(min(ydata), max(ydata), 50)
#combine those back into a dataset to apply the prediction on
z = np.concatenate((xline.reshape(-1,1),yline.reshape(-1,1)), axis = 1)
#call the predictions
zline = reg2.predict(z)
#plot the resulting line.
ax.plot3D(xline, yline, zline, 'black')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
